# %%
## Baseline
# %run -i -t -N5 train.py \
    --model_name baseline \
    --is_baseline
# Out:
# {   'model_name': 'baseline',
#     'is_baseline': True,
#     'data': 'data',
#     'test_size': 0.2,
#     'random_state': 42,
#     'buffer_size': 30000,
#     'batch_size': 32,
#     'lr': 0.0003,
#     'alpha': 0.05,
#     'epochs': 200,
#     'augment': False,
#     'logs': 'logs',
#     'ckpt': 'ckpt'}
# 1 Physical GPUs, 1 Logical GPUs.
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3070, compute capability 8.6
# Deduplicating Results:
#   - apple: 1153 -> 607 (-47.4%)
#   - tomato: 1190 -> 642 (-46.1%)
#   - kiwi: 1172 -> 473 (-59.6%)
#   - plum: 1148 -> 361 (-68.6%)
#   - watermelon: 1138 -> 616 (-45.9%)
#   - Koreanmelon: 1151 -> 428 (-62.8%)
#   - peach: 1168 -> 484 (-58.6%)
#   - mango: 1115 -> 614 (-44.9%)
#   - orange: 1161 -> 398 (-65.7%)
# |train|=2958, |valid|=740, |test|=925
# ...

# %%
## ArcFace
# %run -i -t -N5 train.py \
    --model_name arcface
# Out:
# {   'model_name': 'arcface',
#     'is_baseline': False,
#     'data': 'data',
#     'test_size': 0.2,
#     'random_state': 42,
#     'buffer_size': 30000,
#     'batch_size': 32,
#     'lr': 0.0003,
#     'alpha': 0.05,
#     'epochs': 200,
#     'augment': False,
#     'logs': 'logs',
#     'ckpt': 'ckpt'}
# 1 Physical GPUs, 1 Logical GPUs.
# Deduplicating Results:
#   - apple: 1153 -> 607 (-47.4%)
#   - tomato: 1190 -> 642 (-46.1%)
#   - kiwi: 1172 -> 473 (-59.6%)
#   - plum: 1148 -> 361 (-68.6%)
#   - watermelon: 1138 -> 616 (-45.9%)
#   - Koreanmelon: 1151 -> 428 (-62.8%)
#   - peach: 1168 -> 484 (-58.6%)
#   - mango: 1115 -> 614 (-44.9%)
#   - orange: 1161 -> 398 (-65.7%)
# |train|=2958, |valid|=740, |test|=925
# tr_ds: <PrefetchDataset element_spec=(TensorSpec(shape=(None, 280, 280, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# ...

# %%
## ArcFace + Augmentation
# %run -i -t -N5 train.py \
    --model_name arcface-aug \
    --augment
# Out:
# {   'model_name': 'arcface-aug',
#     'is_baseline': False,
#     'data': 'data',
#     'test_size': 0.2,
#     'random_state': 42,
#     'buffer_size': 30000,
#     'batch_size': 32,
#     'lr': 0.0003,
#     'alpha': 0.05,
#     'epochs': 200,
#     'augment': True,
#     'logs': 'logs',
#     'ckpt': 'ckpt'}
# 1 Physical GPUs, 1 Logical GPUs.
# Deduplicating Results:
#   - apple: 1153 -> 607 (-47.4%)
#   - tomato: 1190 -> 642 (-46.1%)
#   - kiwi: 1172 -> 473 (-59.6%)
#   - plum: 1148 -> 361 (-68.6%)
#   - watermelon: 1138 -> 616 (-45.9%)
#   - Koreanmelon: 1151 -> 428 (-62.8%)
#   - peach: 1168 -> 484 (-58.6%)
#   - mango: 1115 -> 614 (-44.9%)
#   - orange: 1161 -> 398 (-65.7%)
# |train|=2958, |valid|=740, |test|=925
# tr_ds: <PrefetchDataset element_spec=(TensorSpec(shape=(None, 280, 280, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# ...
